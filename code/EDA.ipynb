# %% [markdown]
# basic description of data characteristics - what do your variables look like? Is it what you would expect? Anything of particular note? Did your data cleaning do anything?
# exploratory analysis of variable correlation - does a first-order effect exist? Are there any things of interest to note that might affect future modelling decisions (e.g. Simpson's Paradox, variable transformations)?
